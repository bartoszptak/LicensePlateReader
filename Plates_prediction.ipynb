# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

data_path = 'data'
div = 10

data_set = np.load(os.path.join(data_path, 'arrays', 'cars.npy'))

for im in data_set:
    img = cv2.resize(im[0], (int(1280/div), int(720/div)))
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    im[0] = cv2.equalizeHist(gray)

# %%
X_ = data_set[:, 0:1]
Y_ = data_set[:, 1:9]

Xx = []
Y = []

for x in X_:
    Xx.append(x[0] * 1. / 255)

Xx = np.array(Xx)
Y = np.array(Y_)

Y /= div

X = Xx[..., np.newaxis]

print(len(X), X.shape)
print(len(Y), Y.shape)
# Out:
# 407 (407, 72, 128, 1)
# 407 (407, 8)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Activation, Dense, Dropout, MaxPooling2D, ZeroPadding2D
from keras.optimizers import Adam
np.random.seed(720)
# Out:
# C:\Install\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(72,128,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(8, activation='linear'))

model.compile(loss='mean_absolute_error', optimizer=Adam(lr=0.001, decay=1e-4), metrics=['mean_absolute_error'])

# %%
model.fit(X, Y, epochs=500, batch_size=32, shuffle=True, validation_split=0.2)
# Out:
# WARNING:tensorflow:Variable *= will be deprecated. Use variable.assign_mul if you want assignment to the variable value or 'x = x * y' if you want a new python Tensor object.
# Train on 325 samples, validate on 82 samples
# Epoch 1/500
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# C:\Install\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# C:\Install\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# C:\Install\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# ResourceExhaustedError: OOM when allocating tensor with shape[32,128,36,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: conv2d_4/convolution = Conv2D[T=DT_FLOAT, _class=["loc:@training/Adam/gradients/conv2d_4/convolution_grad/Conv2DBackpropInput"], data_format="NCHW", dilations=[1, 1, 1, 1], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](zero_padding2d_4/Pad, conv2d_4/kernel/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[Node: metrics/mean_absolute_error/Mean_1/_301 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_1967_metrics/mean_absolute_error/Mean_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-5-462973164744> in <module>()
# ----> 1 model.fit(X, Y, epochs=500, batch_size=32, shuffle=True, validation_split=0.2)
#
# C:\Install\Anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# C:\Install\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# C:\Install\Anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# C:\Install\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# C:\Install\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Install\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# C:\Install\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# C:\Install\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[32,128,36,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: conv2d_4/convolution = Conv2D[T=DT_FLOAT, _class=["loc:@training/Adam/gradients/conv2d_4/convolution_grad/Conv2DBackpropInput"], data_format="NCHW", dilations=[1, 1, 1, 1], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](zero_padding2d_4/Pad, conv2d_4/kernel/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[Node: metrics/mean_absolute_error/Mean_1/_301 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_1967_metrics/mean_absolute_error/Mean_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'conv2d_4/convolution', defined at:
#   File "C:\Install\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Install\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Install\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Install\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Install\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "C:\Install\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Install\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Install\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Install\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Install\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Install\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Install\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Install\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Install\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Install\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Install\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Install\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Install\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Install\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Install\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-3f467beeefe4>", line 11, in <module>
#     model.add(Conv2D(128, (3, 3), activation='relu'))
#   File "C:\Install\Anaconda3\lib\site-packages\keras\models.py", line 522, in add
#     output_tensor = layer(self.outputs[0])
#   File "C:\Install\Anaconda3\lib\site-packages\keras\engine\topology.py", line 619, in __call__
#     output = self.call(inputs, **kwargs)
#   File "C:\Install\Anaconda3\lib\site-packages\keras\layers\convolutional.py", line 168, in call
#     dilation_rate=self.dilation_rate)
#   File "C:\Install\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py", line 3341, in conv2d
#     data_format=tf_data_format)
#   File "C:\Install\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 780, in convolution
#     return op(input, filter)
#   File "C:\Install\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 868, in __call__
#     return self.conv_op(inp, filter)
#   File "C:\Install\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 520, in __call__
#     return self.call(inp, filter)
#   File "C:\Install\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 204, in __call__
#     name=self.name)
#   File "C:\Install\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py", line 1042, in conv2d
#     data_format=data_format, dilations=dilations, name=name)
#   File "C:\Install\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Install\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3414, in create_op
#     op_def=op_def)
#   File "C:\Install\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1740, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[32,128,36,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: conv2d_4/convolution = Conv2D[T=DT_FLOAT, _class=["loc:@training/Adam/gradients/conv2d_4/convolution_grad/Conv2DBackpropInput"], data_format="NCHW", dilations=[1, 1, 1, 1], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](zero_padding2d_4/Pad, conv2d_4/kernel/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[Node: metrics/mean_absolute_error/Mean_1/_301 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_1967_metrics/mean_absolute_error/Mean_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
model.save(os.path.join(data_path, 'models', 'cars'))
model.save_weights(os.path.join(data_path, 'weights', 'cars'))

# %%
import matplotlib.pyplot as plt
import cv2

# %%
tests = np.load(os.path.join(data_path, 'arrays', 'cars_only_new.npy'))

for test in tests:

    cv2.circle(test[0], (int(test[1]),int(test[2])), 3, (0,0,255), -1)
    cv2.circle(test[0], (int(test[3]),int(test[4])), 3, (0,0,255), -1)
    cv2.circle(test[0], (int(test[5]),int(test[6])), 3, (0,0,255), -1)
    cv2.circle(test[0], (int(test[7]),int(test[8])), 3, (0,0,255), -1)

    
    cv2.imshow('a', test[0])
    cv2.imwrite(os.path.join(data_path,'cos.jpg', test[0]))
    cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-6aca06bab475> in <module>()
#      10
#      11     cv2.imshow('a', test[0])
# ---> 12     cv2.imwrite(os.path.join(data_path,'cos.jpg', test[0]))
#      13     cv2.waitKey(0)
#      14 cv2.destroyAllWindows()
#
# C:\Install\Anaconda3\lib\ntpath.py in join(path, *paths)
#     112         return result_drive + result_path
#     113     except (TypeError, AttributeError, BytesWarning):
# --> 114         genericpath._check_arg_types('join', path, *paths)
#     115         raise
#     116
#
# C:\Install\Anaconda3\lib\genericpath.py in _check_arg_types(funcname, *args)
#     147         else:
#     148             raise TypeError('%s() argument must be str or bytes, not %r' %
# --> 149                             (funcname, s.__class__.__name__)) from None
#     150     if hasstr and hasbytes:
#     151         raise TypeError("Can't mix strings and bytes in path components") from None
#
# TypeError: join() argument must be str or bytes, not 'ndarray'
